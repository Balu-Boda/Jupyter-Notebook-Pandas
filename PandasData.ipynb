# %%
print(" my name ")
# Out:
#  my name

# %%
a+b
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-ca730b97bf8a> in <module>
# ----> 1 a+b
#
# NameError: name 'a' is not defined

# %%
import os
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'easy_install-3.7.exe',
#  'easy_install.exe',
#  'iptest.exe',
#  'iptest3.exe',
#  'ipython.exe',
#  'ipython3.exe',
#  'jsonschema.exe',
#  'jupyter-bundlerextension.exe',
#  'jupyter-console.exe',
#  'jupyter-kernel.exe',
#  'jupyter-kernelspec.exe',
#  'jupyter-migrate.exe',
#  'jupyter-nbconvert.exe',
#  'jupyter-nbextension.exe',
#  'jupyter-notebook.exe',
#  'jupyter-qtconsole.exe',
#  'jupyter-run.exe',
#  'jupyter-serverextension.exe',
#  'jupyter-troubleshoot.exe',
#  'jupyter-trust.exe',
#  'jupyter.exe',
#  'PandasData.ipynb',
#  'pip.exe',
#  'pip3.7.exe',
#  'pip3.exe',
#  'pygmentize.exe',
#  'pywin32_postinstall.py',
#  'pywin32_testall.py',
#  '__pycache__']

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# You are using pip version 18.1, however version 20.2b1 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %%
import pandas

# %%
df1=pandas.read_csv("C:/Users/Balu/Downloads/original/supermarkets.csv")
df1
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df1=pandas.read_json("C:/Users/Balu/Downloads/original/supermarkets.json")
df1
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
pip install xlrd
# Out:
# ...
# You are using pip version 18.1, however version 20.2b1 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %%
df1=pandas.read_excel("C:/Users/Balu/Downloads/original/supermarkets.xlsx")
df1
# Out:
#    ID          Address           City             State Country  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA
# 1   2   735 Dolores St  San Francisco          CA 94119     USA
# 2   3      332 Hill St  San Francisco  California 94114     USA
# 3   4     3995 23rd St  San Francisco          CA 94114     USA
# 4   5  1056 Sanchez St  San Francisco        California     USA
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA
#
#   Supermarket Name  Number of Employees
# 0          Madeira                    8
# 1      Bready Shop                   15
# 2      Super River                   25
# 3       Ben's Shop                   10
# 4          Sanchez                   12
# 5       Richvalley                   20

# %%
df5=pandas.read_csv("C:/Users/Balu/Downloads/original/supermarkets-semi-colons.txt")
df5
# Out:
#         ID;Address;City;State;Country;Name;Employees
# 0  1;3666 21st St;San Francisco;CA 94114;USA;Made...
# 1  2;735 Dolores St;San Francisco;CA 94119;USA;Br...
# 2  3;332 Hill St;San Francisco;California 94114;U...
# 3  4;3995 23rd St;San Francisco;CA 94114;USA;Ben'...
# 4  5;1056 Sanchez St;San Francisco;California;USA...
# 5  6;551 Alvarado St;San Francisco;CA 94114;USA;R...

# %%
pandas.read_csv?

# %%
df6=pandas.read_csv("C:/Users/Balu/Downloads/original/supermarkets-semi-colons.txt",sep=";")
df6
# Out:
#    ID          Address           City             State Country          Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA       Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA   Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA   Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA    Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA       Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA    Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df7=pandas.read_csv("C:/Users/Balu/Downloads/original/supermarkets-semi-colons.txt",sep=";",header=None)
df7
# Out:
#     0                1              2                 3        4  \
# 0  ID          Address           City             State  Country
# 1   1     3666 21st St  San Francisco          CA 94114      USA
# 2   2   735 Dolores St  San Francisco          CA 94119      USA
# 3   3      332 Hill St  San Francisco  California 94114      USA
# 4   4     3995 23rd St  San Francisco          CA 94114      USA
# 5   5  1056 Sanchez St  San Francisco        California      USA
# 6   6  551 Alvarado St  San Francisco          CA 94114      USA
#
#               5          6
# 0          Name  Employees
# 1       Madeira          8
# 2   Bready Shop         15
# 3   Super River         25
# 4    Ben's Shop         10
# 5       Sanchez         12
# 6    Richvalley         20

# %%
df7.columns=("AB","CD","EF","GH","AB1","CD1","EF1")
df7
# Out:
#    AB               CD             EF                GH      AB1  \
# 0  ID          Address           City             State  Country
# 1   1     3666 21st St  San Francisco          CA 94114      USA
# 2   2   735 Dolores St  San Francisco          CA 94119      USA
# 3   3      332 Hill St  San Francisco  California 94114      USA
# 4   4     3995 23rd St  San Francisco          CA 94114      USA
# 5   5  1056 Sanchez St  San Francisco        California      USA
# 6   6  551 Alvarado St  San Francisco          CA 94114      USA
#
#             CD1        EF1
# 0          Name  Employees
# 1       Madeira          8
# 2   Bready Shop         15
# 3   Super River         25
# 4    Ben's Shop         10
# 5       Sanchez         12
# 6    Richvalley         20

# %%
df1
# Out:
#    ID          Address           City             State Country  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA
# 1   2   735 Dolores St  San Francisco          CA 94119     USA
# 2   3      332 Hill St  San Francisco  California 94114     USA
# 3   4     3995 23rd St  San Francisco          CA 94114     USA
# 4   5  1056 Sanchez St  San Francisco        California     USA
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA
#
#   Supermarket Name  Number of Employees
# 0          Madeira                    8
# 1      Bready Shop                   15
# 2      Super River                   25
# 3       Ben's Shop                   10
# 4          Sanchez                   12
# 5       Richvalley                   20

# %%
df1.set_index("ID")
# Out:
#              City             State Country Supermarket Name  \
# ID
# 1   San Francisco          CA 94114     USA          Madeira
# 2   San Francisco          CA 94119     USA      Bready Shop
# 3   San Francisco  California 94114     USA      Super River
# 4   San Francisco          CA 94114     USA       Ben's Shop
# 5   San Francisco        California     USA          Sanchez
# 6   San Francisco          CA 94114     USA       Richvalley
#
#     Number of Employees
# ID
# 1                     8
# 2                    15
# 3                    25
# 4                    10
# 5                    12
# 6                    20

# %%
df1.set_index("State",inplace=True)
df1
# Out:
#                   ID Country Supermarket Name  Number of Employees
# State
# CA 94114           1     USA          Madeira                    8
# CA 94119           2     USA      Bready Shop                   15
# California 94114   3     USA      Super River                   25
# CA 94114           4     USA       Ben's Shop                   10
# California         5     USA          Sanchez                   12
# CA 94114           6     USA       Richvalley                   20

# %%
df1.set_index("Supermarket Name",inplace=True,drop=False)
df1
# Out:
#                   ID Country Supermarket Name  Number of Employees
# Supermarket Name
# Madeira            1     USA          Madeira                    8
# Bready Shop        2     USA      Bready Shop                   15
# Super River        3     USA      Super River                   25
# Ben's Shop         4     USA       Ben's Shop                   10
# Sanchez            5     USA          Sanchez                   12
# Richvalley         6     USA       Richvalley                   20

# %%
df12=pandas.read_csv("C:/Users/Balu/Downloads/original/supermarkets.csv")
df12
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df12.loc["3":"6","Address":"Country"]
# Out:
#            Address           City       State Country
# 3     3995 23rd St  San Francisco    CA 94114     USA
# 4  1056 Sanchez St  San Francisco  California     USA
# 5  551 Alvarado St  San Francisco    CA 94114     USA

# %%
df12.iloc[2:5,2:6]
# Out:
#             City             State Country         Name
# 2  San Francisco  California 94114     USA  Super River
# 3  San Francisco          CA 94114     USA   Ben's Shop
# 4  San Francisco        California     USA      Sanchez

# %%
df12.drop(df12.columns[2:4],1)
# Out:
#    ID          Address Country         Name  Employees
# 0   1     3666 21st St     USA      Madeira          8
# 1   2   735 Dolores St     USA  Bready Shop         15
# 2   3      332 Hill St     USA  Super River         25
# 3   4     3995 23rd St     USA   Ben's Shop         10
# 4   5  1056 Sanchez St     USA      Sanchez         12
# 5   6  551 Alvarado St     USA   Richvalley         20

# %%
df12.columns
# Out:
# Index(['ID', 'Address', 'City', 'State', 'Country', 'Name', 'Employees'], dtype='object')

# %%
df12["county"]=["north"]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-73-3fd5280044a4> in <module>
# ----> 1 df12["county"]=["north"]
#
# c:\users\balu\appdata\local\programs\python\python37-32\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    2936         else:
#    2937             # set column
# -> 2938             self._set_item(key, value)
#    2939
#    2940     def _setitem_slice(self, key, value):
#
# c:\users\balu\appdata\local\programs\python\python37-32\lib\site-packages\pandas\core\frame.py in _set_item(self, key, value)
#    2998
#    2999         self._ensure_valid_index(value)
# -> 3000         value = self._sanitize_column(key, value)
#    3001         NDFrame._set_item(self, key, value)
#    3002
#
# ...

# %%
df12["county"]=df12.shape[0]*["north"]
df12
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees county
# 0          8  north
# 1         15  north
# 2         25  north
# 3         10  north
# 4         12  north
# 5         20  north

# %%
len(df12.index)
# Out:
# 6

# %%
df12.shape
# Out:
# (6, 8)

# %%
df12.shape[0]
# Out:
# 6

# %%
df12.shape[1]
# Out:
# 8

# %%
df12["county"]=df12["City"]+","+"north"
df12
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees               county
# 0          8  San Francisco,north
# 1         15  San Francisco,north
# 2         25  San Francisco,north
# 3         10  San Francisco,north
# 4         12  San Francisco,north
# 5         20  San Francisco,north

# %%
df12_t=df12.T
df12_t
# Out:
#                              0                    1                    2  \
# ID                           1                    2                    3
# Address           3666 21st St       735 Dolores St          332 Hill St
# City             San Francisco        San Francisco        San Francisco
# State                 CA 94114             CA 94119     California 94114
# Country                    USA                  USA                  USA
# Name                   Madeira          Bready Shop          Super River
# Employees                    8                   15                   25
# county     San Francisco,north  San Francisco,north  San Francisco,north
#
#                              3                    4                    5
# ID                           4                    5                    6
# Address           3995 23rd St      1056 Sanchez St      551 Alvarado St
# City             San Francisco        San Francisco        San Francisco
# ...

# %%
df12_t["7"]=["99","2","one","UK","za","tet1","test2","one"]
df12_t
# Out:
#                              0                    1                    2  \
# ID                           1                    2                    3
# Address           3666 21st St       735 Dolores St          332 Hill St
# City             San Francisco        San Francisco        San Francisco
# State                 CA 94114             CA 94119     California 94114
# Country                    USA                  USA                  USA
# Name                   Madeira          Bready Shop          Super River
# Employees                    8                   15                   25
# county     San Francisco,north  San Francisco,north  San Francisco,north
#
#                              3                    4                    5  \
# ID                           4                    5                    6
# Address           3995 23rd St      1056 Sanchez St      551 Alvarado St
# City             San Francisco        San Francisco        San Francisco
# ...

# %%
df13=df12_t.T
df13
# Out:
#               ID          Address           City             State Country  \
# 0              1     3666 21st St  San Francisco          CA 94114     USA
# 1              2   735 Dolores St  San Francisco          CA 94119     USA
# 2              3      332 Hill St  San Francisco  California 94114     USA
# 3              4     3995 23rd St  San Francisco          CA 94114     USA
# 4              5  1056 Sanchez St  San Francisco        California     USA
# 5              6  551 Alvarado St  San Francisco          CA 94114     USA
# my details  test                2            one                UK      za
# 7             99                2            one                UK      za
#
#                    Name Employees               county
# 0               Madeira         8  San Francisco,north
# 1           Bready Shop        15  San Francisco,north
# 2           Super River        25  San Francisco,north
# 3            Ben's Shop        10  San Francisco,north
# ...
